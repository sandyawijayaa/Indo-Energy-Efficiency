# %%
import nbconvert
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.stats import norm
import math

# %%
energy = pd.read_csv("[131] Energy Consumption.csv")
unemployment = pd.read_csv("/work/[131] Full Unemployment.csv")
homeowners = pd.read_csv("/work/[131] Homeowners.csv")
household_work = pd.read_csv("/work/[131] Household working.csv")
life_expect = pd.read_csv("/work/[131] Life Expectancy.csv")
population = pd.read_csv("/work/[131] Population.csv")
school_inattendance = pd.read_csv("/work/[131] School Inattendance.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_521/1085010050.py in <module>
# ----> 1 energy = pd.read_csv("[131] Energy Consumption.csv")
#       2 unemployment = pd.read_csv("/work/[131] Full Unemployment.csv")
#       3 homeowners = pd.read_csv("/work/[131] Homeowners.csv")
#       4 household_work = pd.read_csv("/work/[131] Household working.csv")
#       5 life_expect = pd.read_csv("/work/[131] Life Expectancy.csv")
#
# ...

# %%
unemployment.drop([0,1])
# Out:
#                                              Provinsi  \
# 2                                                ACEH
# 3                                      SUMATERA UTARA
# 4                                      SUMATERA BARAT
# 5                                                RIAU
# 6                                               JAMBI
# 7                                    SUMATERA SELATAN
# 8                                            BENGKULU
# 9                                             LAMPUNG
# 10                               KEP. BANGKA BELITUNG
# 11                                          KEP. RIAU
# 12                                        DKI JAKARTA
# 13                                         JAWA BARAT
# 14                                        JAWA TENGAH
# 15                                      DI YOGYAKARTA
# 16                                         JAWA TIMUR
# 17                                             BANTEN
# ...

# %%
energy
# Out:
#                 Provinsi  \
# 0                    NaN
# 1                   ACEH
# 2         SUMATERA UTARA
# 3         SUMATERA BARAT
# 4                   RIAU
# 5                  JAMBI
# 6       SUMATERA SELATAN
# 7               BENGKULU
# 8                LAMPUNG
# 9   KEP. BANGKA BELITUNG
# 10             KEP. RIAU
# 11           DKI JAKARTA
# 12            JAWA BARAT
# 13           JAWA TENGAH
# 14         DI YOGYAKARTA
# 15            JAWA TIMUR
# 16                BANTEN
# 17                  BALI
# 18   NUSA TENGGARA BARAT
# 19   NUSA TENGGARA TIMUR
# 20      KALIMANTAN BARAT
# 21     KALIMANTAN TENGAH
# 22    KALIMANTAN SELATAN
# 23      KALIMANTAN TIMUR
# 24      KALIMANTAN UTARA
# 25        SULAWESI UTARA
# 26       SULAWESI TENGAH
# 27      SULAWESI SELATAN
# 28     SULAWESI TENGGARA
# 29             GORONTALO
# 30        SULAWESI BARAT
# 31                MALUKU
# 32          MALUKU UTARA
# 33           PAPUA BARAT
# 34                 PAPUA
# ...

# %%
unemployment
# Out:
#                                              Provinsi  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                ACEH
# 3                                      SUMATERA UTARA
# 4                                      SUMATERA BARAT
# 5                                                RIAU
# 6                                               JAMBI
# 7                                    SUMATERA SELATAN
# 8                                            BENGKULU
# 9                                             LAMPUNG
# 10                               KEP. BANGKA BELITUNG
# 11                                          KEP. RIAU
# 12                                        DKI JAKARTA
# 13                                         JAWA BARAT
# 14                                        JAWA TENGAH
# 15                                      DI YOGYAKARTA
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=9a2d3571-826e-4759-814d-0768207fd99f' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
